# %% [markdown]
# ##Set up the Environment

# %%
#Clone the Yolov5 repo
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies
# !pip install labelImg
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17075, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 17075 (delta 29), reused 30 (delta 12), pack-reused 17022 (from 1)
# Receiving objects: 100% (17075/17075), 15.69 MiB | 17.63 MiB/s, done.
# Resolving deltas: 100% (11724/11724), done.
# /content/yolov5/yolov5
# ...

# %% [markdown]
# ##Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Training YOLOv5 on a Video Dataset

# %%
video_path = '/content/drive/MyDrive/penguins_in_zoo.mp4'

# Run YOLOv5 inference on the sample image
# !python detect.py --weights yolov5s.pt --source $video_path --conf 0.4 --save-txt --save-conf
# Out:
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/penguins_in_zoo.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-389-ge62a31b6 Python-3.10.12 torch-2.5.1+cu121 CPU
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 116MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# video 1/1 (1/767) /content/drive/MyDrive/penguins_in_zoo.mp4: 384x640 4 birds, 453.0ms
# video 1/1 (2/767) /content/drive/MyDrive/penguins_in_zoo.mp4: 384x640 4 birds, 459.5ms
# video 1/1 (3/767) /content/drive/MyDrive/penguins_in_zoo.mp4: 384x640 4 birds, 269.7ms
# ...

# %%
# !ls runs/detect/exp
# Out:
# labels	penguins_in_zoo.mp4

# %%
from IPython.display import Video
Video('/content/drive/MyDrive/penguins_in_zoo.mp4', width=600, height=400, embed=True)

# %%
from google.colab import files
files.download('runs/detect/exp/penguins_in_zoo.mp4')
